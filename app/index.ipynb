# %%
from idc_index import index

client = index.IDCClient()
query = f"""
select collection_id
from index
group by collection_id
order by collection_id asc
"""
df = client.sql_query(query)
result = df.to_json(orient="records")
result
# Out:
# '[{"collection_id":"4d_lung"},{"collection_id":"acrin_6698"},{"collection_id":"acrin_contralateral_breast_mr"},{"collection_id":"acrin_flt_breast"},{"collection_id":"acrin_nsclc_fdg_pet"},{"collection_id":"adrenal_acc_ki67_seg"},{"collection_id":"advanced_mri_breast_lesions"},{"collection_id":"anti_pd_1_lung"},{"collection_id":"b_mode_and_ceus_liver"},{"collection_id":"breast_cancer_screening_dbt"},{"collection_id":"breast_diagnosis"},{"collection_id":"breast_mri_nact_pilot"},{"collection_id":"c4kc_kits"},{"collection_id":"cc_tumor_heterogeneity"},{"collection_id":"cmb_aml"},{"collection_id":"cmb_crc"},{"collection_id":"cmb_gec"},{"collection_id":"cmb_lca"},{"collection_id":"cmb_mel"},{"collection_id":"cmb_mml"},{"collection_id":"cmb_pca"},{"collection_id":"cmmd"},{"collection_id":"colorectal_liver_metastases"},{"collection_id":"covid_19_ar"},{"collection_id":"covid_19_ny_sbu"},{"collection_id":"cptac_aml"},{"collection_id":"cptac_brca"},{"collection_id":"cptac_ccrcc"},{"collection_id":"cptac_cm"},{"collection_id":"cptac_coad"},{"collection_id":"cptac_gbm"},{"collection_id":"cptac_hnscc"},{"collection_id":"cptac_lscc"},{"collection_id":"cptac_luad"},{"collection_id":"cptac_ov"},{"collection_id":"cptac_pda"},{"collection_id":"cptac_sar"},{"collection_id":"cptac_ucec"},{"collection_id":"ct_colonography"},{"collection_id":"ct_lymph_nodes"},{"collection_id":"ct_phantom4radiomics"},{"collection_id":"ct_vs_pet_ventilation_imaging"},{"collection_id":"ctpred_sunitinib_pannet"},{"collection_id":"dro_toolkit"},{"collection_id":"duke_breast_cancer_mri"},{"collection_id":"ea1141"},{"collection_id":"gbm_dsc_mri_dro"},{"collection_id":"hcc_tace_seg"},{"collection_id":"htan_hms"},{"collection_id":"htan_ohsu"},{"collection_id":"htan_vanderbilt"},{"collection_id":"htan_wustl"},{"collection_id":"icdc_glioma"},{"collection_id":"ispy1"},{"collection_id":"ispy2"},{"collection_id":"lctsc"},{"collection_id":"lidc_idri"},{"collection_id":"lung_fused_ct_pathology"},{"collection_id":"lung_pet_ct_dx"},{"collection_id":"lung_phantom"},{"collection_id":"lungct_diagnosis"},{"collection_id":"midrc_ricord_1a"},{"collection_id":"midrc_ricord_1b"},{"collection_id":"midrc_ricord_1c"},{"collection_id":"mouse_astrocytoma"},{"collection_id":"mouse_mammary"},{"collection_id":"naf_prostate"},{"collection_id":"nlm_visible_human_project"},{"collection_id":"nlst"},{"collection_id":"nsclc_radiogenomics"},{"collection_id":"nsclc_radiomics"},{"collection_id":"nsclc_radiomics_genomics"},{"collection_id":"nsclc_radiomics_interobserver1"},{"collection_id":"pancreas_ct"},{"collection_id":"pancreatic_ct_cbct_seg"},{"collection_id":"pdmr_292921_168_r"},{"collection_id":"pdmr_425362_245_t"},{"collection_id":"pdmr_521955_158_r4"},{"collection_id":"pdmr_833975_119_r"},{"collection_id":"pdmr_997537_175_t"},{"collection_id":"pdmr_bl0293_f563"},{"collection_id":"pdmr_texture_analysis"},{"collection_id":"pediatric_ct_seg"},{"collection_id":"pelvic_reference_data"},{"collection_id":"phantom_fda"},{"collection_id":"prostate_3t"},{"collection_id":"prostate_anatomical_edge_cases"},{"collection_id":"prostate_diagnosis"},{"collection_id":"prostate_fused_mri_pathology"},{"collection_id":"prostate_mri"},{"collection_id":"prostate_mri_us_biopsy"},{"collection_id":"prostatex"},{"collection_id":"pseudo_phi_dicom_data"},{"collection_id":"qiba_ct_1c"},{"collection_id":"qin_breast"},{"collection_id":"qin_breast_dce_mri"},{"collection_id":"qin_lung_ct"},{"collection_id":"qin_prostate_repeatability"},{"collection_id":"remind"},{"collection_id":"rider_breast_mri"},{"collection_id":"rider_lung_ct"},{"collection_id":"rider_lung_pet_ct"},{"collection_id":"rider_pilot"},{"collection_id":"rms_mutation_prediction"},{"collection_id":"soft_tissue_sarcoma"},{"collection_id":"spie_aapm_lung_ct_challenge"},{"collection_id":"stageii_colorectal_ct"},{"collection_id":"tcga_acc"},{"collection_id":"tcga_blca"},{"collection_id":"tcga_brca"},{"collection_id":"tcga_cesc"},{"collection_id":"tcga_chol"},{"collection_id":" ...

# %%
import json
from IPython.display import HTML, display

data = json.loads(result)

# Convert JSON to HTML table
html_table = "<table><tr><th>collection_id</th></tr>"
for record in data:
    html_table += "<tr><td>{}</td></tr>".format(record['collection_id'])
html_table += "</table>"

# Display HTML table in Jupyter Notebook
display(HTML(html_table))
# Out:
# <table><tr><th>collection_id</th></tr><tr><td>4d_lung</td></tr><tr><td>acrin_6698</td></tr><tr><td>acrin_contralateral_breast_mr</td></tr><tr><td>acrin_flt_breast</td></tr><tr><td>acrin_nsclc_fdg_pet</td></tr><tr><td>adrenal_acc_ki67_seg</td></tr><tr><td>advanced_mri_breast_lesions</td></tr><tr><td>anti_pd_1_lung</td></tr><tr><td>b_mode_and_ceus_liver</td></tr><tr><td>breast_cancer_screening_dbt</td></tr><tr><td>breast_diagnosis</td></tr><tr><td>breast_mri_nact_pilot</td></tr><tr><td>c4kc_kits</td></tr><tr><td>cc_tumor_heterogeneity</td></tr><tr><td>cmb_aml</td></tr><tr><td>cmb_crc</td></tr><tr><td>cmb_gec</td></tr><tr><td>cmb_lca</td></tr><tr><td>cmb_mel</td></tr><tr><td>cmb_mml</td></tr><tr><td>cmb_pca</td></tr><tr><td>cmmd</td></tr><tr><td>colorectal_liver_metastases</td></tr><tr><td>covid_19_ar</td></tr><tr><td>covid_19_ny_sbu</td></tr><tr><td>cptac_aml</td></tr><tr><td>cptac_brca</td></tr><tr><td>cptac_ccrcc</td></tr><tr><td>cptac_cm</td></tr><tr><td>cptac_coad</td></tr><tr><td>cptac_gbm</td></tr><tr><td>cptac_hnscc</td></tr><tr><td>cptac_lscc</td></tr><tr><td>cptac_luad</td></tr><tr><td>cptac_ov</td></tr><tr><td>cptac_pda</td></tr><tr><td>cptac_sar</td></tr><tr><td>cptac_ucec</td></tr><tr><td>ct_colonography</td></tr><tr><td>ct_lymph_nodes</td></tr><tr><td>ct_phantom4radiomics</td></tr><tr><td>ct_vs_pet_ventilation_imaging</td></tr><tr><td>ctpred_sunitinib_pannet</td></tr><tr><td>dro_toolkit</td></tr><tr><td>duke_breast_cancer_mri</td></tr><tr><td>ea1141</td></tr><tr><td>gbm_dsc_mri_dro</td></tr><tr><td>hcc_tace_seg</td></tr><tr><td>htan_hms</td></tr><tr><td>htan_ohsu</td></tr><tr><td>htan_vanderbilt</td></tr><tr><td>htan_wustl</td></tr><tr><td>icdc_glioma</td></tr><tr><td>ispy1</td></tr><tr><td>ispy2</td></tr><tr><td>lctsc</td></tr><tr><td>lidc_idri</td></tr><tr><td>lung_fused_ct_pathology</td></tr><tr><td>lung_pet_ct_dx</td></tr><tr><td>lung_phantom</td></tr><tr><td>lungct_diagnosis</td></tr><tr><td>midrc_ricord_1a</td></tr><tr><td>midrc_ricord_1b</td></tr><tr><td>midrc_ricord_1c</td></tr><tr><td>mouse_astrocytoma</td></tr><tr><td>mouse_mammary</td></tr><tr><td>naf_prostate</td></tr><tr><td>nlm_visible_human_project</td></tr><tr><td>nlst</td></tr><tr><td>nsclc_radiogenomics</td></tr><tr><td>nsclc_radiomics</td></tr><tr><td>nsclc_radiomics_genomics</td></tr><tr><td>nsclc_radiomics_interobserver1</td></tr><tr><td>pancreas_ct</td></tr><tr><td>pancreatic_ct_cbct_seg</td></tr><tr><td>pdmr_292921_168_r</td></tr><tr><td>pdmr_425362_245_t</td></tr><tr><td>pdmr_521955_158_r4</td></tr><tr><td>pdmr_833975_119_r</td></tr><tr><td>pdmr_997537_175_t</td></tr><tr><td>pdmr_bl0293_f563</td></tr><tr><td>pdmr_texture_analysis</td></tr><tr><td>pediatric_ct_seg</td></tr><tr><td>pelvic_reference_data</td></tr><tr><td>phantom_fda</td></tr><tr><td>prostate_3t</td></tr><tr><td>prostate_anatomical_edge_cases</td></tr><tr><td>prostate_diagnosis</td></tr><tr><td>prostate_fused_mri_pathology</td></tr><tr><td>prostate_mri</td></tr><tr><td>prostate_mri_us_biopsy</td></tr><tr><td>prostatex</td></tr><tr><td>pseudo_phi_dicom_data</td></tr><tr><td>qiba_ct_1c</td></tr><tr><td>qin_breast</td></tr><tr><td>qin_breast_dce_mri</td></tr><tr><td>qin_lung_ct</td></tr><tr><td>qin_prostate_repeatability</td></tr><tr><td>remind</td></tr><tr><td>rider_breast_mri</td></tr><tr><td>rider_lung_ct</td></tr><tr><td>rider_lung_pet_ct</td></tr><tr><td>rider_pilot</td></tr><tr><td>rms_mutation_prediction</td></tr><tr><td>soft_tissue_sarcoma</td></tr><tr><td>spie_aapm_lung_ct_challenge</td></tr><tr><td>stageii_colorectal_ct</td></tr><tr><td>tcga_acc</td></tr><tr><td>tcga_blca</td></tr><tr><td>tcga_brca</td></tr><tr><td>tcga_cesc</td></tr><tr><td>tcga_chol</td></tr><tr><td>tcga_coad</td></tr><tr><td>tcga_dlbc</td></tr><tr><td>tcga_esca</td></tr><tr><td>tcga_gbm</td></tr><tr><td>tcga_hnsc</td></tr><tr><td>tcga_kich</td></tr><tr><td>tcga_kirc</td></tr><tr><td>tcga_kirp</td></tr><tr><td>tcga_lgg</td></tr><tr><td>tcga_lihc</td></tr><tr><td>tcga_luad</td></tr><tr><td>tcga_lusc</td>< ...

# %%
from idc_index import index

client = index.IDCClient()
query = f"""
select *
from index
"""
#query = f"""
#select StudyInstanceUID, SeriesInstanceUID, series_aws_url, collection_id, PatientID, StudyDate, PatientAge, "Modality", "Manufacturer", "ManufacturerModelName", collection_id, "StudyDate", "StudyDescription", "SeriesDescription", collection_id
#from index
#"""
df = client.sql_query(query)
# fields not found in idc index: ImageType, Patient Weight, SliceThickness, PixelSpacing, tcia_species, tcia_tumorLocation
result = df.columns
result
# Out:
# Index(['collection_id', 'analysis_result_id', 'PatientID', 'SeriesInstanceUID',
#        'StudyInstanceUID', 'source_DOI', 'PatientAge', 'PatientSex',
#        'StudyDate', 'StudyDescription', 'BodyPartExamined', 'Modality',
#        'Manufacturer', 'ManufacturerModelName', 'SeriesDate',
#        'SeriesDescription', 'SeriesNumber', 'instanceCount',
#        'license_short_name', 'series_aws_url', 'series_size_MB'],
#       dtype='object')

# %%
import subprocess

def get_collections():
    client = index.IDCClient()
    query = f"""
    select collection_id
    from index
    group by collection_id
    order by collection_id asc
    """
    df = client.sql_query(query)
    #result = df.to_json(orient="records")
    #result = df.values.tolist()
    result_list = [item for sublist in df.values.tolist() for item in sublist]
    #result_string = ','.join(result_list)
    return result_list

def get_patients(collection, filters):
    client = index.IDCClient()
    
    query = f"""
    select PatientID
    from index
    where collection_id = '{collection}'
    """
    
    df = client.sql_query(query)
    df_unique = df.drop_duplicates()
    patient_ids = df_unique['PatientID'].tolist()

    if filters:
        filtered_patient_ids = filter_primary_sites(patient_ids, filters)
        # Update patient_ids to only include filtered IDs
        patient_ids = "\"" + "\",\"".join(patient_ids) + "\""
        #patient_ids = filtered_patient_ids.split(',') if filtered_patient_ids else []

    result = jsonify(patient_ids)
    return result

# $patient_ids = "TCGA-EY-A214,TCGA-02-0003"
# $primary_sites = "Brain"
# $results = "TCGA-02-0003" because TCGA-02-0003 has primary sites Brain but TCGA-EY-A214
# curl -sX GET "http://index:5000/patients/tcga_ov/Brain"
def filter_primary_sites(patient_ids, primary_sites):
    if primary_sites is None or primary_sites == "":
        return patient_ids
    
    include_or_exclude = "in"   
    #include_or_exclude = "ex"

    patient_ids = "\"" + "\",\"".join(patient_ids.split(',')) + "\""
    primary_sites = "\"" + "\",\"".join(primary_sites.split(',')) + "\""

    command = f"curl -s --data 'filters={{\"op\":\"and\",\"content\":[{{\"op\":\"in\",\"content\":{{\"field\":\"cases.submitter_id\",\"value\":[{patient_ids}]}}}},{{\"op\":\"{include_or_exclude}\",\"content\":{{\"field\":\"cases.primary_site\",\"value\":[{primary_sites}]}}}}]}}&fields=case_id,submitter_id,primary_site&size=10' 'https://api.gdc.cancer.gov/cases' | jq -r '.data.hits | map(.submitter_id) | join(\",\")'"
    
    output = subprocess.check_output(command, shell=True, text=True, stderr=subprocess.STDOUT)
    return output.strip()

def filter_experimental_strategies(patient_ids, experimental_strategies):
    if experimental_strategies is None or experimental_strategies == "":
        return patient_ids
        
    patient_ids = "\"" + "\",\"".join(patient_ids.split(',')) + "\""
    experimental_strategies = "\"" + "\",\"".join(experimental_strategies.split(',')) + "\""

    command = f"curl -s --data 'filters={{\"op\":\"and\",\"content\":[{{\"op\":\"in\",\"content\":{{\"field\":\"cases.submitter_id\",\"value\":[{patient_ids}]}}}}]}}&fields=files.experimental_strategy,submitter_id&size=10' https://api.gdc.cancer.gov/cases| jq -r '.data.hits[] | select(.files[].experimental_strategy | IN({experimental_strategies})) | .submitter_id' | sort -u"

    output = subprocess.check_output(command, shell=True, text=True, stderr=subprocess.STDOUT)
    return output.strip()

# if collections is None:
#     collections = get_collections()
collections = get_collections()

# %%
collections_str = ','.join(collections)
collections_str
# Out:
# '4d_lung,acrin_6698,acrin_contralateral_breast_mr,acrin_flt_breast,acrin_nsclc_fdg_pet,adrenal_acc_ki67_seg,advanced_mri_breast_lesions,anti_pd_1_lung,b_mode_and_ceus_liver,breast_cancer_screening_dbt,breast_diagnosis,breast_mri_nact_pilot,c4kc_kits,cc_tumor_heterogeneity,cmb_aml,cmb_crc,cmb_gec,cmb_lca,cmb_mel,cmb_mml,cmb_pca,cmmd,colorectal_liver_metastases,covid_19_ar,covid_19_ny_sbu,cptac_aml,cptac_brca,cptac_ccrcc,cptac_cm,cptac_coad,cptac_gbm,cptac_hnscc,cptac_lscc,cptac_luad,cptac_ov,cptac_pda,cptac_sar,cptac_ucec,ct_colonography,ct_lymph_nodes,ct_phantom4radiomics,ct_vs_pet_ventilation_imaging,ctpred_sunitinib_pannet,dro_toolkit,duke_breast_cancer_mri,ea1141,gbm_dsc_mri_dro,hcc_tace_seg,htan_hms,htan_ohsu,htan_vanderbilt,htan_wustl,icdc_glioma,ispy1,ispy2,lctsc,lidc_idri,lung_fused_ct_pathology,lung_pet_ct_dx,lung_phantom,lungct_diagnosis,midrc_ricord_1a,midrc_ricord_1b,midrc_ricord_1c,mouse_astrocytoma,mouse_mammary,naf_prostate,nlm_visible_human_project,nlst,nsclc_radiogenomics,nsclc_radiomics,nsclc_radiomics_genomics,nsclc_radiomics_interobserver1,pancreas_ct,pancreatic_ct_cbct_seg,pdmr_292921_168_r,pdmr_425362_245_t,pdmr_521955_158_r4,pdmr_833975_119_r,pdmr_997537_175_t,pdmr_bl0293_f563,pdmr_texture_analysis,pediatric_ct_seg,pelvic_reference_data,phantom_fda,prostate_3t,prostate_anatomical_edge_cases,prostate_diagnosis,prostate_fused_mri_pathology,prostate_mri,prostate_mri_us_biopsy,prostatex,pseudo_phi_dicom_data,qiba_ct_1c,qin_breast,qin_breast_dce_mri,qin_lung_ct,qin_prostate_repeatability,remind,rider_breast_mri,rider_lung_ct,rider_lung_pet_ct,rider_pilot,rms_mutation_prediction,soft_tissue_sarcoma,spie_aapm_lung_ct_challenge,stageii_colorectal_ct,tcga_acc,tcga_blca,tcga_brca,tcga_cesc,tcga_chol,tcga_coad,tcga_dlbc,tcga_esca,tcga_gbm,tcga_hnsc,tcga_kich,tcga_kirc,tcga_kirp,tcga_lgg,tcga_lihc,tcga_luad,tcga_lusc,tcga_meso,tcga_ov,tcga_paad,tcga_pcpg,tcga_prad,tcga_read,tcga_sarc,tcga_skcm,tcga_stad,tcga_tgct,tcga_thca,tcga_thym,tcga_ucec,tcga_ucs,tcga_uvm,upenn_gbm,vestibular_schwannoma_mc_rc,vestibular_schwannoma_seg,victre'

# %%
patients = get_patients('TCGA-GBM')
patients_str = ','.join(patients)
# #print(patients_str)
print(len(patients))

# filtered_patients = filter_primary_sites(patients_str, "Breast")
filtered_patients_str = filter_primary_sites(patients_str, "Brain")
filtered_patients = filtered_patients_str.split(',')
print(len(filtered_patients))
print(filtered_patients)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 patients = get_patients('TCGA-GBM')
#       2 patients_str = ','.join(patients)
#       3 # #print(patients_str)
#
# TypeError: get_patients() missing 1 required positional argument: 'filters'

# %%
#filtered_patients = filter_primary_sites(patients_str, 'Breast')
filtered_patients = filter_primary_sites("TCGA-EY-A214,TCGA-BH-A0GY,TCGA-02-0003", "Breast")
#filtered_patients = filter_primary_sites("TCGA-EY-A214,TCGA-BH-A0GY,TCGA-02-0003", "")
filtered_patients
# Out:
# 'TCGA-BH-A0GY'

# %%
#select = 'select PatientID from index '
select = 'select * from index '
key = 'PatientID'
where = 'where 1 = 1'
values = filtered_patients.split(',')
if len(values) > 0:
    where += " and " + key + " in ('" + "','".join(values) + "')"
else:
    where += " and " + key + " = " + value + "'"

client = index.IDCClient()
query = select + where
print(query)
df = client.sql_query(query)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       3 key = 'PatientID'
#       4 where = 'where 1 = 1'
# ----> 5 values = filtered_patients.split(',')
#       6 if len(values) > 0:
#       7     where += " and " + key + " in ('" + "','".join(values) + "')"
#
# NameError: name 'filtered_patients' is not defined

# %%
df['series_aws_url']
# Out:
# 0     s3://idc-open-data/25d0a388-67fe-4fc3-9b93-b17...
# 1     s3://idc-open-data/6a37f4a0-aeda-4b1d-9945-e6d...
# 2     s3://idc-open-data/6ea28924-2058-4933-b72c-aad...
# 3     s3://idc-open-data/1c6eac41-33fc-4372-a201-036...
# 4     s3://idc-open-data/df866683-b180-47db-ac04-c5f...
# 5     s3://idc-open-data/a8a6b4d8-0c0a-4e49-b40e-189...
# 6     s3://idc-open-data/447342ef-c225-49f4-8dd4-659...
# 7     s3://idc-open-data/54d23b21-843d-4931-8ea5-300...
# 8     s3://idc-open-data/7992bbaf-0ba9-4814-96f3-8ff...
# 9     s3://idc-open-data/61ec2800-b4cd-45d4-a5b8-354...
# 10    s3://idc-open-data/9c1215aa-ab97-4480-a523-0d6...
# 11    s3://idc-open-data/f69bb966-fbda-41cc-af4a-f2b...
# 12    s3://idc-open-data/c2ff8d6f-5783-4bcf-a051-39b...
# 13    s3://idc-open-data/1e4939ae-492d-46e9-b3e6-1c6...
# 14    s3://idc-open-data/5d1e2e48-6874-4f5f-b689-473...
# 15    s3://idc-open-data/01a52e2d-a05d-4c00-9f3e-bec...
# 16    s3://idc-open-data/03553c0a-b248-4b00-8ba8-566...
# Name: series_aws_url, dtype: object

# %%
import os
import sys
import shutil

def execute_command(command, output=True):
    try:
        result = subprocess.run(command, shell=True, text=True, capture_output=True, check=True)
        result = result.stdout.strip() if result.stdout else ""
    except subprocess.CalledProcessError as e:
        result = e.stderr.strip()
    if output:
        return result

def download_dicom_dir(aws_s3_path):
    aws_profile = "default"  # Adjust as needed
    aws_config_dir = "/root/.aws/"
    os.environ['AWS_CONFIG_FILE'] = os.path.join(aws_config_dir, 'config')
    os.environ['AWS_SHARED_CREDENTIALS_FILE'] = os.path.join(aws_config_dir, 'credentials')

    dicom_dir = aws_s3_path.split("/")[-2]
    dicom_tar_file = dicom_dir + ".tgz"

    if not os.path.exists(dicom_tar_file):
        execute_command(f"aws s3 s3://idc-open-data/{dicom_dir}/ /app/{dicom_dir} --recursive", output=False)
        execute_command(f"tar -czvf {dicom_tar_file} /app/{dicom_dir}")
        shutil.rmtree(dicom_dir)

    if os.path.exists(dicom_tar_file):
        return dicom_tar_file

# download dicom dir
download_dicom_dir(df['series_aws_url'][0])
# Out:
# '25d0a388-67fe-4fc3-9b93-b1720b4e7129.tgz'

# %%
#select = 'select PatientID from index '
select = 'select * from index '
key = 'PatientID'
where = 'where 1 = 1'
values = patients_str.split(',')
if len(values) > 0:
    where += " and " + key + " in ('" + "','".join(values) + "')"
else:
    where += " and " + key + " = " + value + "'"

client = index.IDCClient()
query = select + where
print(query)
df = client.sql_query(query)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       3 key = 'PatientID'
#       4 where = 'where 1 = 1'
# ----> 5 values = patients_str.split(',')
#       6 if len(values) > 0:
#       7     where += " and " + key + " in ('" + "','".join(values) + "')"
#
# NameError: name 'patients_str' is not defined

# %%
filter_primary_sites("Breast_MRI_001", "Breast")
# Out:
# ''

# %%
filter_primary_sites("TCGA-EY-A214,TCGA-BH-A0GY,TCGA-02-0003", "Breast")
# Out:
# 'TCGA-BH-A0GY'

# %%
from idc_index import index
import subprocess

#from flask import jsonify
import json

def filter_primary_sites(patient_ids, primary_sites):
    if primary_sites is None or primary_sites == "":
        return patient_ids
    
    include_or_exclude = "in"
    #include_or_exclude = "ex"

    patient_ids = "\"" + "\",\"".join(patient_ids.split(',')) + "\""
    primary_sites = "\"" + "\",\"".join(primary_sites.split(',')) + "\""

    command = f"curl -s --data 'filters={{\"op\":\"and\",\"content\":[{{\"op\":\"in\",\"content\":{{\"field\":\"cases.submitter_id\",\"value\":[{patient_ids}]}}}},{{\"op\":\"{include_or_exclude}\",\"content\":{{\"field\":\"cases.primary_site\",\"value\":[{primary_sites}]}}}}]}}&fields=case_id,submitter_id,primary_site&size=10' 'https://api.gdc.cancer.gov/cases' | jq -r '.data.hits | map(.submitter_id) | join(\",\")'"
    
    output = subprocess.check_output(command, shell=True, text=True, stderr=subprocess.STDOUT)
    return output.strip()
    
def get_patients(collection, filters):
    client = index.IDCClient()
    
    query = f"""
    select PatientID
    from index
    where collection_id = '{collection}'
    """
    
    df = client.sql_query(query)
    df_unique = df.drop_duplicates()
    patient_ids = df_unique['PatientID'].tolist()

    if filters:
        patient_ids = ",".join(patient_ids)
        filtered_patient_ids = filter_primary_sites(patient_ids, filters)

    #result = jsonify(patient_ids) # for flask only
    result = json.dumps(data)
    return result

get_patients("tcga_ov", "Brain")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[14], line 40
#      37     result = jsonify(patient_ids)
#      38     return result
# ---> 40 get_patients("tcga_ov", "Brain")
#
# Cell In[14], line 37, in get_patients(collection, filters)
#      34     patient_ids = ",".join(patient_ids)
#      35     filtered_patient_ids = filter_primary_sites(patient_ids, filters)
# ---> 37 result = jsonify(patient_ids)
#      38 return result
#
# File /usr/local/lib/python3.9/site-packages/flask/json/__init__.py:170, in jsonify(*args, **kwargs)
#     138 def jsonify(*args: t.Any, **kwargs: t.Any) -> Response:
#     139     """Serialize the given arguments as JSON, and return a
#     140     :class:`~flask.Response` object with the ``application/json``
#     141     mimetype. A dict or list returned from a view will be converted to a
#    (...)
#     168     .. versionadded:: 0.2
#     169     """
# --> 170     return current_app.json.response(*args, **kwargs)
#
# File /usr/local/lib/python3.9/site-packages/werkzeug/local.py:311, in _ProxyLookup.__get__(self, instance, owner)
#     308     return self
#     310 try:
# --> 311     obj = instance._get_current_object()
#     312 except RuntimeError:
#     313     if self.fallback is None:
#
# File /usr/local/lib/python3.9/site-packages/werkzeug/local.py:508, in LocalProxy.__init__.<locals>._get_current_object()
#     506     obj = local.get()
#     507 except LookupError:
# --> 508     raise RuntimeError(unbound_message) from None
#     510 return get_name(obj)
#
# RuntimeError: Working outside of application context.
#
# This typically means that you attempted to use functionality that needed
# the current application. To solve this, set up an application context
# with app.app_context(). See the documentation for more information.

# %%
import requests
import json

def get_genomic_data_uuids(patient_id, data_categories=None, data_types=None, experimental_strategies=None):
    """
    Get genomic data file UUIDs for a given PatientID with optional filters.
    
    Args:
    patient_id (str): The patient ID to query.
    data_categories (list): Optional list of data categories to filter by.
    data_types (list): Optional list of data types to filter by.
    experimental_strategies (list): Optional list of experimental strategies to filter by.
    
    Returns:
    A list of dictionaries, each containing 'uuid', 'data_type', 'data_category', and 'experimental_strategy' for available genomic data.
    """
    base_url = "https://api.gdc.cancer.gov/files"
    
    filters = {
        "op": "and",
        "content": [
            {
                "op": "in",
                "content": {
                    "field": "cases.submitter_id",
                    "value": [patient_id]
                }
            }
        ]
    }
    
    if data_categories:
        filters["content"].append({
            "op": "in",
            "content": {
                "field": "data_category",
                "value": data_categories
            }
        })
    
    if data_types:
        filters["content"].append({
            "op": "in",
            "content": {
                "field": "data_type",
                "value": data_types
            }
        })
    
    if experimental_strategies:
        filters["content"].append({
            "op": "in",
            "content": {
                "field": "experimental_strategy",
                "value": experimental_strategies
            }
        })
    
    params = {
        "filters": json.dumps(filters),
        "fields": "file_id,data_type,data_category,experimental_strategy",
        "format": "JSON",
        "size": "100"
    }
    
    response = requests.get(base_url, params=params)
    
    if response.status_code == 200:
        data = response.json()
        return [{
            "uuid": hit["file_id"],
            "data_type": hit["data_type"],
            "data_category": hit["data_category"],
            "experimental_strategy": hit.get("experimental_strategy", "N/A")
        } for hit in data["data"]["hits"]]
    else:
        print(f"Error: {response.status_code}")
        return []

# Test the function with a sample patient ID and various filters
sample_patient_id = "TCGA-AC-A3W5"  # Replace with a valid patient ID from your dataset

print("Test 1: No filters")
results = get_genomic_data_uuids(sample_patient_id)
print(f"Genomic data for patient {sample_patient_id}:")
for item in results:
    print(f"UUID: {item['uuid']}, Data Type: {item['data_type']}, Data Category: {item['data_category']}, Experimental Strategy: {item['experimental_strategy']}")

print("\nTest 2: Filter by data category")
results = get_genomic_data_uuids(sample_patient_id, data_categories=["Transcriptome Profiling"])
print(f"Genomic data for patient {sample_patient_id} (Transcriptome Profiling only):")
for item in results:
    print(f"UUID: {item['uuid']}, Data Type: {item['data_type']}, Data Category: {item['data_category']}, Experimental Strategy: {item['experimental_strategy']}")

print("\nTest 3: Filter by data type")
results = get_genomic_data_uuids(sample_patient_id, data_types=["Gene Expression Quantification"])
print(f"Genomic data for patient {sample_patient_id} (Gene Expression Quantification only):")
for item in results:
    print(f"UUID: {item['uuid']}, Data Type: {item['data_type']}, Data Category: {item['data_category']}, Experimental Strategy: {item['experimental_strategy']}")

print("\nTest 4: Filter by experimental strategy")
results = get_genomic_data_uuids(sample_patient_id, experimental_strategies=["RNA-Seq"])
print(f"Genomic data for patient {sample_patient_id} (RNA-Seq only):")
for item in results:
    print(f"UUID: {item['uuid']}, Data Type: {item['data_type']}, Data Category: {item['data_category']}, Experimental Strategy: {item['experimental_strategy']}")

print("\nTest 5: Combining multiple filters")
results = get_genomic_data_uuids(sample_patient_id, 
                                 data_categories=["Transcriptome Profiling"],
                                 data_types=["Gene Expression Quantification"],
                                 experimental_strategies=["RNA-Seq"])
print(f"Genomic data for patient {sample_patient_id} (Transcriptome Profiling, Gene Expression Quantification, RNA-Seq):")
for item in results:
    print(f"UUID: {item['uuid']}, Data Type: {item['data_type']}, Data Category: {item['data_category']}, Experimental Strategy: {item['experimental_strategy']}")

# Generate download URLs
base_download_url = "https://api.gdc.cancer.gov/data/"
print("\nDownload links for filtered results:")
for item in results:
    download_url = f"{base_download_url}{item['uuid']}"
    print(f"  {item['data_type']} ({item['experimental_strategy']}): {download_url}")
# Out:
# Test 1: No filters
# Genomic data for patient TCGA-AC-A3W5:
# UUID: a88c168e-4bba-4bd2-9c0c-77934444cc1c, Data Type: Clinical Supplement, Data Category: Clinical, Experimental Strategy: N/A
# UUID: 0a40467f-9495-4c5b-b56e-3347a3ee0572, Data Type: Clinical Supplement, Data Category: Clinical, Experimental Strategy: N/A
# UUID: 950ee56c-df20-4b39-867e-c73f17d0f4f6, Data Type: Biospecimen Supplement, Data Category: Biospecimen, Experimental Strategy: N/A
# UUID: 62d4515f-a30b-4b1a-b2dd-c8bf9476e803, Data Type: Clinical Supplement, Data Category: Clinical, Experimental Strategy: N/A
# UUID: c5039e7e-14d8-4e59-ba20-0d3fa38b86df, Data Type: Biospecimen Supplement, Data Category: Biospecimen, Experimental Strategy: N/A
# UUID: c10090b8-fa42-4e32-86a0-9dedceb5b605, Data Type: Biospecimen Supplement, Data Category: Biospecimen, Experimental Strategy: N/A
# UUID: d0c967b5-78ee-4bc4-9493-3cbe44af1bf5, Data Type: Biospecimen Supplement, Data Category: Biospecimen, Experimental Strategy: N/A
# UUID: 8162d394-8b64-4da2-9f5b-d164c54b9608, Data Type: Clinical Supplement, Data Category: Clinical, Experimental Strategy: N/A
# UUID: 403b5cef-8173-47c7-b56a-cc94dcfbb2e3, Data Type: Clinical Supplement, Data Category: Clinical, Experimental Strategy: N/A
# UUID: 1e6b79ff-9787-4cbe-b19d-ebabb6b43589, Data Type: Clinical Supplement, Data Category: Clinical, Experimental Strategy: N/A
# UUID: 41fd4c6c-2932-4c6b-914f-7abaea9dc8a0, Data Type: Biospecimen Supplement, Data Category: Biospecimen, Experimental Strategy: N/A
# UUID: 22656b71-476a-4b5f-9f3b-82afb29a34bc, Data Type: Biospecimen Supplement, Data Category: Biospecimen, Experimental Strategy: N/A
# UUID: edbb5de2-d0b5-4a07-a0e1-19e952a5117d, Data Type: Biospecimen Supplement, Data Category: Biospecimen, Experimental Strategy: N/A
# UUID: a9baecf0-5549-4396-8805-a6d1681d11cd, Data Type: Clinical Supplement, Data Category: Clinical, Experimental Strategy: N/A
# UUID: 43569ab9-5a32-45ef-a07e-e93f45416a16, Data Type: Biospecimen Supplement, Data Category: Biospecimen, Experimental Strategy: N/A
# UUID: a24d7574-e419-47ce-9293-b9b29f854a10, Data Type: Biospecimen Supplement, Data Category: Biospecimen, Experimental Strategy: N/A
# UUID: 22f38342-3f1a-47e5-9025-c19719fa21d0, Data Type: Clinical Supplement, Data Category: Clinical, Experimental Strategy: N/A
# UUID: f434b393-9e32-4ca2-aa1a-3b0de36b5ffe, Data Type: Clinical Supplement, Data Category: Clinical, Experimental Strategy: N/A
# UUID: 5907be67-69f6-4339-8264-952a2462bea5, Data Type: Biospecimen Supplement, Data Category: Biospecimen, Experimental Strategy: N/A
# UUID: b5fd0411-7565-4801-874b-6c88b13733b6, Data Type: Clinical Supplement, Data Category: Clinical, Experimental Strategy: N/A
# UUID: c15d7887-3e27-4456-bd6b-34bf48a9db4e, Data Type: Raw Simple Somatic Mutation, Data Category: Simple Nucleotide Variation, Experimental Strategy: WXS
# UUID: 38406d21-f213-4d98-b45f-a8516478edb5, Data Type: Masked Copy Number Segment, Data Category: Copy Number Variation, Experimental Strategy: Genotyping Array
# UUID: a15f37c5-1b76-44d3-9fb2-2755d90d6562, Data Type: Slide Image, Data Category: Biospecimen, Experimental Strategy: Tissue Slide
# UUID: 5e863e9f-1449-4a38-ac00-cfd7c21ba6e2, Data Type: Gene Expression Quantification, Data Category: Transcriptome Profiling, Experimental Strategy: RNA-Seq
# UUID: 902542d4-5653-4883-97f7-923500a712ee, Data Type: Gene Level Copy Number, Data Category: Copy Number Variation, Experimental Strategy: Genotyping Array
# UUID: 94a961a8-af2b-4da3-a58f-8fa05dc8d8fb, Data Type: Annotated Somatic Mutation, Data Category: Simple Nucleotide Variation, Experimental Strategy: WXS
# UUID: bb733e98-3a54-47c8-b08e-622bac96a62f, Data Type: Aligned Reads, Data Category: Sequencing Reads, Experimental Strategy: RNA-Seq
# UUID: cd417f97-ab71-4f0a-8e3a-0b9077f94638, Data Type: Simple Germline Variation, Data Category: Simple Nucleotide Variation, Experimental Strategy: Genotyping Array
# UUID: 24371099-70d6-4869-aa83-04d0fed53f42, Data Type: Aligned Reads, Data Category: Sequencing Reads, Experimental Strategy: WGS
# UUID: 0bdedc35-7f54-45e9-b18d-198c1ef4694e, Data Type: Annotated Somatic Mutation, Data Category: Simple Nucleotide Variation, Experimental Strategy: WXS
# UUID: aa8ade7e-f57c-4ba6-88d5-7e1e3d341443, Data Type: Isoform Expression Quantification, Data Category: Transcriptome Profiling, Experimental Strategy: miRNA-Seq
# UUID: 9425fe04-6b2f-4adc-aa53-b0cfeb74cebf, Data Type: Aligned Reads, Data Category: Sequencing Reads, Experimental Strategy: WXS
# UUID: 2727f6d7-4f4b-4651-9807-3312c52befd3, Data Type: Aligned Reads, Data Category: Sequencing Reads, Experimental Strategy: RNA-Seq
# UUID: 82c4d5ae-ea1b-45d5-aedf-609edf0bcbd4, Data Type: Annotated Somatic Mutation, Data Category: Simple Nucleotide Variation, Experimental Strategy: WXS
# UUID: f7f48058-1476-46e6-88c0-b313a12b59bd, Data Type: Aligned Reads, Data Category: Sequencing Reads, Experimental Strategy: WXS
# UUID: ebd13509-602b-4e8e-aad8-9be5cae2890c, Data Type: Simple Germline Variation, Data Category: Simple Nucleotide Variation, Experimental Strategy: Genotyping Array
# UUID: bf3fd5be-f72c-4edb-966e-a1dcf5395963, Data Type: Splice Junction Quantification, Data Category: Transcriptome Profiling, Experimental Strategy: RNA-Seq
# UUID: 1675394d-373f-4f64-996a-8d847c648caf, Data Type: Annotated Somatic Mutation, Data Category: Simple Nucleotide Variation, Experimental Strategy: WXS
# UUID: a93315ad-063e-443b-baec-6368d1c37785, Data Type: Clinical Supplement, Data Category: Clinical, Experimental Strategy: N/A
# UUID: c71acc1f-5752-4cc3-99f4-46133befea86, Data Type: Raw Intensities, Data Category: Copy Number Variation, Experimental Strategy: Genotyping Array
# UUID: 3e63c528-6403-4781-8555-2daaf4b0d1dd, Data Type: Allele-specific Copy Number Segment, Data Category: Copy Number Variation, Experimental Strategy: Genotyping Array
# UUID: 08a63743-09a2-4f30-8948-765c45c64aa7, Data Type: Aligned Reads, Data Category: Sequencing Reads, Experimental Strategy: miRNA-Seq
# UUID: aa931745-919a-4687-82ed-34c4d1e53fe1, Data Type: Transcript Fusion, Data Category: Structural Variation, Experimental Strategy: RNA-Seq
# UUID: 0fa12edb-9b16-4ba2-ae3c-929b93d5dcb8, Data Type: Slide Image, Data Category: Biospecimen, Experimental Strategy: Diagnostic Slide
# UUID: 8f7ed391-4e7b-48e2-8f0d-b441c837fb61, Data Type: Biospecimen Supplement, Data Category: Biospecimen, Experimental Strategy: N/A
# UUID: 94a8563f-27a0-4e1f-821b-0d7d0e46bee3, Data Type: Aligned Reads, Data Category: Sequencing Reads, Experimental Strategy: RNA-Seq
# UUID: e06aedec-9ec6-4558-809d-587bff328966, Data Type: Annotated Somatic Mutation, Data Category: Simple Nucleotide Variation, Experimental Strategy: WXS
# UUID: 89b4b795-8716-4704-830e-91381919399c, Data Type: Copy Number Segment, Data Category: Copy Number Variation, Experimental Strategy: Genotyping Array
# UUID: 27109933-254a-4ada-a5d0-556453b79fd3, Data Type: Protein Expression Quantification, Data Category: Proteome Profiling, Experimental Strategy: Reverse Phase Protein Array
# UUID: 769647dd-c77a-43a0-b9f3-401fec6f84ab, Data Type: Annotated Somatic Mutation, Data Category: Simple Nucleotide Variation, Experimental Strategy: WXS
# UUID: f4f690cc-6725-46de-a53b-f6f3c143ea89, Data Type: Raw Simple Somatic Mutation, Data Category: Simple Nucleotide Variation, Experimental Strategy: WXS
# UUID: 61cd84d3-2659-4e92-a1f7-69023377383b, Data Type: Methylation Beta Value, Data Category: DNA Methylation, Experimental Strategy: Methylation Array
# UUID: 76f936eb-7bca-4bf8-9210-35a6b0c4970d, Data Type: Annotated Somatic Mutation, Data Category: Simple Nucleotide Variation, Experimental Strategy: WXS
# UUID: e8a263d7-4230-4bec-92ab-8b80be0000fc, Data Type: Gene Level Copy Number, Data Category: Copy Number Variation, Experimental Strategy: Genotyping Array
# UUID: d766dfe0-ea00-479f-8d1d-82ecb98dd2a9, Data Type: Raw Simple Somatic Mutation, Data Category: Simple Nucleotide Variation, Experimental Strategy: WXS
# UUID: f8ebd592-e64d-4387-8704-ca83c5610e35, Data Type: Raw Intensities, Data Category: Copy Number Variation, Experimental Strategy: Genotyping Array
# UUID: 3547414c-7f4e-49b4-813f-bc1dbf103fe9, Data Type: Transcript Fusion, Data Category: Structural Variation, Experimental Strategy: RNA-Seq
# UUID: 95d72a48-88b5-49a4-80aa-6e39f9821979, Data Type: Masked Intensities, Data Category: DNA Methylation, Experimental Strategy: Methylation Array
# UUID: 50e2d5d6-0678-4db7-b849-df7ccd20d424, Data Type: Raw Simple Somatic Mutation, Data Category: Simple Nucleotide Variation, Experimental Strategy: WXS
# UUID: ebf1e95b-4505-420a-9e2b-c552733ceef6, Data Type: Transcript Fusion, Data Category: Structural Variation, Experimental Strategy: RNA-Seq
# UUID: 70c28a05-d777-4f2b-943d-2d5d09ad1c20, Data Type: Annotated Somatic Mutation, Data Category: Simple Nucleotide Variation, Experimental Strategy: WXS
# UUID: dab7a763-f3c8-4532-acb6-1c72f8f29265, Data Type: Transcript Fusion, Data Category: Structural Variation, Experimental Strategy: RNA-Seq
# UUID: d05e1fe7-e3c9-4205-abac-c1f57ccddad6, Data Type: Biospecimen Supplement, Data Category: Biospecimen, Experimental Strategy: N/A
# UUID: d3480f1c-a301-4799-9d11-afdf81a8bef7, Data Type: Copy Number Segment, Data Category: Copy Number Variation, Experimental Strategy: Genotyping Array
# UUID: 3ada67b6-bcdd-4682-b99b-89956219718c, Data Type: miRNA Expression Quantification, Data Category: Transcriptome Profiling, Experimental Strategy: miRNA-Seq
# UUID: 234a8d5e-2ad6-4ace-b8fc-e575a8903263, Data Type: Masked Intensities, Data Category: DNA Methylation, Experimental Strategy: Methylation Array
# UUID: 49d506d7-09be-4eaa-b1eb-ff7207bd02e3, Data Type: Allele-specific Copy Number Segment, Data Category: Copy Number Variation, Experimental Strategy: Genotyping Array
# UUID: c78d5190-ac60-4af0-a50a-14183e685b9c, Data Type: Gene Level Copy Number, Data Category: Copy Number Variation, Experimental Strategy: Genotyping Array
# UUID: fa117dd4-b55e-411a-96d1-0b22eb0913af, Data Type: Masked Copy Number Segment, Data Category: Copy Number Variation, Experimental Strategy: Genotyping Array
# UUID: be7ad45d-05de-4cc8-83d2-3bebaf45d6bd, Data Type: Pathology Report, Data Category: Clinical, Experimental Strategy: N/A
# UUID: b6aa44b9-8ac4-4b7e-9bee-56e741c7b7fc, Data Type: Aligned Reads, Data Category: Sequencing Reads, Experimental Strategy: WGS
#
# Test 2: Filter by data category
# Genomic data for patient TCGA-AC-A3W5 (Transcriptome Profiling only):
# UUID: 5e863e9f-1449-4a38-ac00-cfd7c21ba6e2, Data Type: Gene Expression Quantification, Data Category: Transcriptome Profiling, Experimental Strategy: RNA-Seq
# UUID: aa8ade7e-f57c-4ba6-88d5-7e1e3d341443, Data Type: Isoform Expression Quantification, Data Category: Transcriptome Profiling, Experimental Strategy: miRNA-Seq
# UUID: bf3fd5be-f72c-4edb-966e-a1dcf5395963, Data Type: Splice Junction Quantification, Data Category: Transcriptome Profiling, Experimental Strategy: RNA-Seq
# UUID: 3ada67b6-bcdd-4682-b99b-89956219718c, Data Type: miRNA Expression Quantification, Data Category: Transcriptome Profiling, Experimental Strategy: miRNA-Seq
#
# Test 3: Filter by data type
# Genomic data for patient TCGA-AC-A3W5 (Gene Expression Quantification only):
# UUID: 5e863e9f-1449-4a38-ac00-cfd7c21ba6e2, Data Type: Gene Expression Quantification, Data Category: Transcriptome Profiling, Experimental Strategy: RNA-Seq
#
# Test 4: Filter by experimental strategy
# Genomic data for patient TCGA-AC-A3W5 (RNA-Seq only):
# UUID: 5e863e9f-1449-4a38-ac00-cfd7c21ba6e2, Data Type: Gene Expression Quantification, Data Category: Transcriptome Profiling, Experimental Strategy: RNA-Seq
# UUID: bb733e98-3a54-47c8-b08e-622bac96a62f, Data Type: Aligned Reads, Data Category: Sequencing Reads, Experimental Strategy: RNA-Seq
# UUID: 2727f6d7-4f4b-4651-9807-3312c52befd3, Data Type: Aligned Reads, Data Category: Sequencing Reads, Experimental Strategy: RNA-Seq
# UUID: bf3fd5be-f72c-4edb-966e-a1dcf5395963, Data Type: Splice Junction Quantification, Data Category: Transcriptome Profiling, Experimental Strategy: RNA-Seq
# UUID: aa931745-919a-4687-82ed-34c4d1e53fe1, Data Type: Transcript Fusion, Data Category: Structural Variation, Experimental Strategy: RNA-Seq
# UUID: 94a8563f-27a0-4e1f-821b-0d7d0e46bee3, Data Type: Aligned Reads, Data Category: Sequencing Reads, Experimental Strategy: RNA-Seq
# UUID: 3547414c-7f4e-49b4-813f-bc1dbf103fe9, Data Type: Transcript Fusion, Data Category: Structural Variation, Experimental Strategy: RNA-Seq
# UUID: ebf1e95b-4505-420a-9e2b-c552733ceef6, Data Type: Transcript Fusion, Data Category: Structural Variation, Experimental Strategy: RNA-Seq
# UUID: dab7a763-f3c8-4532-acb6-1c72f8f29265, Data Type: Transcript Fusion, Data Category: Structural Variation, Experimental Strategy: RNA-Seq
#
# Test 5: Combining multiple filters
# Genomic data for patient TCGA-AC-A3W5 (Transcriptome Profiling, Gene Expression Quantification, RNA-Seq):
# UUID: 5e863e9f-1449-4a38-ac00-cfd7c21ba6e2, Data Type: Gene Expression Quantification, Data Category: Transcriptome Profiling, Experimental Strategy: RNA-Seq
#
# Download links for filtered results:
#   Gene Expression Quantification (RNA-Seq): https://api.gdc.cancer.gov/data/5e863e9f-1449-4a38-ac00-cfd7c21ba6e2

# %%
get_genomic_data_uuids('TCGA-AC-A3W5')
# Out:
# [{'uuid': 'a88c168e-4bba-4bd2-9c0c-77934444cc1c',
#   'data_type': 'Clinical Supplement',
#   'data_category': 'Clinical',
#   'experimental_strategy': 'N/A'},
#  {'uuid': '0a40467f-9495-4c5b-b56e-3347a3ee0572',
#   'data_type': 'Clinical Supplement',
#   'data_category': 'Clinical',
#   'experimental_strategy': 'N/A'},
#  {'uuid': '950ee56c-df20-4b39-867e-c73f17d0f4f6',
#   'data_type': 'Biospecimen Supplement',
#   'data_category': 'Biospecimen',
#   'experimental_strategy': 'N/A'},
#  {'uuid': '62d4515f-a30b-4b1a-b2dd-c8bf9476e803',
#   'data_type': 'Clinical Supplement',
#   'data_category': 'Clinical',
#   'experimental_strategy': 'N/A'},
#  {'uuid': 'c5039e7e-14d8-4e59-ba20-0d3fa38b86df',
#   'data_type': 'Biospecimen Supplement',
#   'data_category': 'Biospecimen',
#   'experimental_strategy': 'N/A'},
#  {'uuid': 'c10090b8-fa42-4e32-86a0-9dedceb5b605',
#   'data_type': 'Biospecimen Supplement',
#   'data_category': 'Biospecimen',
#   'experimental_strategy': 'N/A'},
#  {'uuid': 'd0c967b5-78ee-4bc4-9493-3cbe44af1bf5',
#   'data_type': 'Biospecimen Supplement',
#   'data_category': 'Biospecimen',
#   'experimental_strategy': 'N/A'},
#  {'uuid': '8162d394-8b64-4da2-9f5b-d164c54b9608',
#   'data_type': 'Clinical Supplement',
#   'data_category': 'Clinical',
#   'experimental_strategy': 'N/A'},
#  {'uuid': '403b5cef-8173-47c7-b56a-cc94dcfbb2e3',
#   'data_type': 'Clinical Supplement',
#   'data_category': 'Clinical',
#   'experimental_strategy': 'N/A'},
#  {'uuid': '1e6b79ff-9787-4cbe-b19d-ebabb6b43589',
#   'data_type': 'Clinical Supplement',
#   'data_category': 'Clinical',
#   'experimental_strategy': 'N/A'},
#  {'uuid': '41fd4c6c-2932-4c6b-914f-7abaea9dc8a0',
#   'data_type': 'Biospecimen Supplement',
#   'data_category': 'Biospecimen',
#   'experimental_strategy': 'N/A'},
#  {'uuid': '22656b71-476a-4b5f-9f3b-82afb29a34bc',
#   'data_type': 'Biospecimen Supplement',
#   'data_category': 'Biospecimen',
#   'experimental_strategy': 'N/A'},
#  {'uuid': 'edbb5de2-d0b5-4a07-a0e1-19e952a5117d',
#   'data_type': 'Biospecimen Supplement',
#   'data_category': 'Biospecimen',
#   'experimental_strategy': 'N/A'},
#  {'uuid': 'a9baecf0-5549-4396-8805-a6d1681d11cd',
#   'data_type': 'Clinical Supplement',
#   'data_category': 'Clinical',
#   'experimental_strategy': 'N/A'},
#  {'uuid': '43569ab9-5a32-45ef-a07e-e93f45416a16',
#   'data_type': 'Biospecimen Supplement',
#   'data_category': 'Biospecimen',
#   'experimental_strategy': 'N/A'},
#  {'uuid': 'a24d7574-e419-47ce-9293-b9b29f854a10',
#   'data_type': 'Biospecimen Supplement',
#   'data_category': 'Biospecimen',
#   'experimental_strategy': 'N/A'},
#  {'uuid': '22f38342-3f1a-47e5-9025-c19719fa21d0',
#   'data_type': 'Clinical Supplement',
#   'data_category': 'Clinical',
#   'experimental_strategy': 'N/A'},
#  {'uuid': 'f434b393-9e32-4ca2-aa1a-3b0de36b5ffe',
#   'data_type': 'Clinical Supplement',
#   'data_category': 'Clinical',
#   'experimental_strategy': 'N/A'},
#  {'uuid': '5907be67-69f6-4339-8264-952a2462bea5',
#   'data_type': 'Biospecimen Supplement',
#   'data_category': 'Biospecimen',
#   'experimental_strategy': 'N/A'},
#  {'uuid': 'b5fd0411-7565-4801-874b-6c88b13733b6',
#   'data_type': 'Clinical Supplement',
#   'data_category': 'Clinical',
#   'experimental_strategy': 'N/A'},
#  {'uuid': 'c15d7887-3e27-4456-bd6b-34bf48a9db4e',
#   'data_type': 'Raw Simple Somatic Mutation',
#   'data_category': 'Simple Nucleotide Variation',
#   'experimental_strategy': 'WXS'},
#  {'uuid': '38406d21-f213-4d98-b45f-a8516478edb5',
#   'data_type': 'Masked Copy Number Segment',
#   'data_category': 'Copy Number Variation',
#   'experimental_strategy': 'Genotyping Array'},
#  {'uuid': 'a15f37c5-1b76-44d3-9fb2-2755d90d6562',
#   'data_type': 'Slide Image',
#   'data_category': 'Biospecimen',
#   'experimental_strategy': 'Tissue Slide'},
#  {'uuid': '5e863e9f-1449-4a38-ac00-cfd7c21ba6e2',
#   'data_type': 'Gene Expression Quantification',
#   'data_category': 'Transcriptome Profiling',
#   'experimental_strategy': 'RNA-Seq'},
#  {'uuid': '902542d4-5653-4883-97f7-923500a712ee',
#   'data_type': 'Gene Level Copy Number',
#   'data_category': 'Copy Number Variation',
#   'experimental_strategy': 'Genotyping Array'},
#  {'uuid': '94a961a8-af2b-4da3-a58f-8fa05dc8d8fb',
#   'data_type': 'Annotated Somatic Mutation',
#   'data_category': 'Simple Nucleotide Variation',
#   'experimental_strategy': 'WXS'},
#  {'uuid': 'bb733e98-3a54-47c8-b08e-622bac96a62f',
#   'data_type': 'Aligned Reads',
#   'data_category': 'Sequencing Reads',
#   'experimental_strategy': 'RNA-Seq'},
#  {'uuid': 'cd417f97-ab71-4f0a-8e3a-0b9077f94638',
#   'data_type': 'Simple Germline Variation',
#   'data_category': 'Simple Nucleotide Variation',
#   'experimental_strategy': 'Genotyping Array'},
#  {'uuid': '24371099-70d6-4869-aa83-04d0fed53f42',
#   'data_type': 'Aligned Reads',
#   'data_category': 'Sequencing Reads',
#   'experimental_strategy': 'WGS'},
#  {'uuid': '0bdedc35-7f54-45e9-b18d-198c1ef4694e',
#   'data_type': 'Annotated Somatic Mutation',
#   'data_category': 'Simple Nucleotide Variation',
#   'experimental_strategy': 'WXS'},
#  {'uuid': 'aa8ade7e-f57c-4ba6-88d5-7e1e3d341443',
#   'data_type': 'Isoform Expression Quantification',
#   'data_category': 'Transcriptome Profiling',
#   'experimental_strategy': 'miRNA-Seq'},
#  {'uuid': '9425fe04-6b2f-4adc-aa53-b0cfeb74cebf',
#   'data_type': 'Aligned Reads',
#   'data_category': 'Sequencing Reads',
#   'experimental_strategy': 'WXS'},
#  {'uuid': '2727f6d7-4f4b-4651-9807-3312c52befd3',
#   'data_type': 'Aligned Reads',
#   'data_category': 'Sequencing Reads',
#   'experimental_strategy': 'RNA-Seq'},
#  {'uuid': '82c4d5ae-ea1b-45d5-aedf-609edf0bcbd4',
#   'data_type': 'Annotated Somatic Mutation',
#   'data_category': 'Simple Nucleotide Variation',
#   'experimental_strategy': 'WXS'},
#  {'uuid': 'f7f48058-1476-46e6-88c0-b313a12b59bd',
#   'data_type': 'Aligned Reads',
#   'data_category': 'Sequencing Reads',
#   'experimental_strategy': 'WXS'},
#  {'uuid': 'ebd13509-602b-4e8e-aad8-9be5cae2890c',
#   'data_type': 'Simple Germline Variation',
#   'data_category': 'Simple Nucleotide Variation',
#   'experimental_strategy': 'Genotyping Array'},
#  {'uuid': 'bf3fd5be-f72c-4edb-966e-a1dcf5395963',
#   'data_type': 'Splice Junction Quantification',
#   'data_category': 'Transcriptome Profiling',
#   'experimental_strategy': 'RNA-Seq'},
#  {'uuid': '1675394d-373f-4f64-996a-8d847c648caf',
#   'data_type': 'Annotated Somatic Mutation',
#   'data_category': 'Simple Nucleotide Variation',
#   'experimental_strategy': 'WXS'},
#  {'uuid': 'a93315ad-063e-443b-baec-6368d1c37785',
#   'data_type': 'Clinical Supplement',
#   'data_category': 'Clinical',
#   'experimental_strategy': 'N/A'},
#  {'uuid': 'c71acc1f-5752-4cc3-99f4-46133befea86',
#   'data_type': 'Raw Intensities',
#   'data_category': 'Copy Number Variation',
#   'experimental_strategy': 'Genotyping Array'},
#  {'uuid': '3e63c528-6403-4781-8555-2daaf4b0d1dd',
#   'data_type': 'Allele-specific Copy Number Segment',
#   'data_category': 'Copy Number Variation',
#   'experimental_strategy': 'Genotyping Array'},
#  {'uuid': '08a63743-09a2-4f30-8948-765c45c64aa7',
#   'data_type': 'Aligned Reads',
#   'data_category': 'Sequencing Reads',
#   'experimental_strategy': 'miRNA-Seq'},
#  {'uuid': 'aa931745-919a-4687-82ed-34c4d1e53fe1',
#   'data_type': 'Transcript Fusion',
#   'data_category': 'Structural Variation',
#   'experimental_strategy': 'RNA-Seq'},
#  {'uuid': '0fa12edb-9b16-4ba2-ae3c-929b93d5dcb8',
#   'data_type': 'Slide Image',
#   'data_category': 'Biospecimen',
#   'experimental_strategy': 'Diagnostic Slide'},
#  {'uuid': '8f7ed391-4e7b-48e2-8f0d-b441c837fb61',
#   'data_type': 'Biospecimen Supplement',
#   'data_category': 'Biospecimen',
#   'experimental_strategy': 'N/A'},
#  {'uuid': '94a8563f-27a0-4e1f-821b-0d7d0e46bee3',
#   'data_type': 'Aligned Reads',
#   'data_category': 'Sequencing Reads',
#   'experimental_strategy': 'RNA-Seq'},
#  {'uuid': 'e06aedec-9ec6-4558-809d-587bff328966',
#   'data_type': 'Annotated Somatic Mutation',
#   'data_category': 'Simple Nucleotide Variation',
#   'experimental_strategy': 'WXS'},
#  {'uuid': '89b4b795-8716-4704-830e-91381919399c',
#   'data_type': 'Copy Number Segment',
#   'data_category': 'Copy Number Variation',
#   'experimental_strategy': 'Genotyping Array'},
#  {'uuid': '27109933-254a-4ada-a5d0-556453b79fd3',
#   'data_type': 'Protein Expression Quantification',
#   'data_category': 'Proteome Profiling',
#   'experimental_strategy': 'Reverse Phase Protein Array'},
#  {'uuid': '769647dd-c77a-43a0-b9f3-401fec6f84ab',
#   'data_type': 'Annotated Somatic Mutation',
#   'data_category': 'Simple Nucleotide Variation',
#   'experimental_strategy': 'WXS'},
#  {'uuid': 'f4f690cc-6725-46de-a53b-f6f3c143ea89',
#   'data_type': 'Raw Simple Somatic Mutation',
#   'data_category': 'Simple Nucleotide Variation',
#   'experimental_strategy': 'WXS'},
#  {'uuid': '61cd84d3-2659-4e92-a1f7-69023377383b',
#   'data_type': 'Methylation Beta Value',
#   'data_category': 'DNA Methylation',
#   'experimental_strategy': 'Methylation Array'},
#  {'uuid': '76f936eb-7bca-4bf8-9210-35a6b0c4970d',
#   'data_type': 'Annotated Somatic Mutation',
#   'data_category': 'Simple Nucleotide Variation',
#   'experimental_strategy': 'WXS'},
#  {'uuid': 'e8a263d7-4230-4bec-92ab-8b80be0000fc',
#   'data_type': 'Gene Level Copy Number',
#   'data_category': 'Copy Number Variation',
#   'experimental_strategy': 'Genotyping Array'},
#  {'uuid': 'd766dfe0-ea00-479f-8d1d-82ecb98dd2a9',
#   'data_type': 'Raw Simple Somatic Mutation',
#   'data_category': 'Simple Nucleotide Variation',
#   'experimental_strategy': 'WXS'},
#  {'uuid': 'f8ebd592-e64d-4387-8704-ca83c5610e35',
#   'data_type': 'Raw Intensities',
#   'data_category': 'Copy Number Variation',
#   'experimental_strategy': 'Genotyping Array'},
#  {'uuid': '3547414c-7f4e-49b4-813f-bc1dbf103fe9',
#   'data_type': 'Transcript Fusion',
#   'data_category': 'Structural Variation',
#   'experimental_strategy': 'RNA-Seq'},
#  {'uuid': '95d72a48-88b5-49a4-80aa-6e39f9821979',
#   'data_type': 'Masked Intensities',
#   'data_category': 'DNA Methylation',
#   'experimental_strategy': 'Methylation Array'},
#  {'uuid': '50e2d5d6-0678-4db7-b849-df7ccd20d424',
#   'data_type': 'Raw Simple Somatic Mutation',
#   'data_category': 'Simple Nucleotide Variation',
#   'experimental_strategy': 'WXS'},
#  {'uuid': 'ebf1e95b-4505-420a-9e2b-c552733ceef6',
#   'data_type': 'Transcript Fusion',
#   'data_category': 'Structural Variation',
#   'experimental_strategy': 'RNA-Seq'},
#  {'uuid': '70c28a05-d777-4f2b-943d-2d5d09ad1c20',
#   'data_type': 'Annotated Somatic Mutation',
#   'data_category': 'Simple Nucleotide Variation',
#   'experimental_strategy': 'WXS'},
#  {'uuid': 'dab7a763-f3c8-4532-acb6-1c72f8f29265',
#   'data_type': 'Transcript Fusion',
#   'data_category': 'Structural Variation',
#   'experimental_strategy': 'RNA-Seq'},
#  {'uuid': 'd05e1fe7-e3c9-4205-abac-c1f57ccddad6',
#   'data_type': 'Biospecimen Supplement',
#   'data_category': 'Biospecimen',
#   'experimental_strategy': 'N/A'},
#  {'uuid': 'd3480f1c-a301-4799-9d11-afdf81a8bef7',
#   'data_type': 'Copy Number Segment',
#   'data_category': 'Copy Number Variation',
#   'experimental_strategy': 'Genotyping Array'},
#  {'uuid': '3ada67b6-bcdd-4682-b99b-89956219718c',
#   'data_type': 'miRNA Expression Quantification',
#   'data_category': 'Transcriptome Profiling',
#   'experimental_strategy': 'miRNA-Seq'},
#  {'uuid': '234a8d5e-2ad6-4ace-b8fc-e575a8903263',
#   'data_type': 'Masked Intensities',
#   'data_category': 'DNA Methylation',
#   'experimental_strategy': 'Methylation Array'},
#  {'uuid': '49d506d7-09be-4eaa-b1eb-ff7207bd02e3',
#   'data_type': 'Allele-specific Copy Number Segment',
#   'data_category': 'Copy Number Variation',
#   'experimental_strategy': 'Genotyping Array'},
#  {'uuid': 'c78d5190-ac60-4af0-a50a-14183e685b9c',
#   'data_type': 'Gene Level Copy Number',
#   'data_category': 'Copy Number Variation',
#   'experimental_strategy': 'Genotyping Array'},
#  {'uuid': 'fa117dd4-b55e-411a-96d1-0b22eb0913af',
#   'data_type': 'Masked Copy Number Segment',
#   'data_category': 'Copy Number Variation',
#   'experimental_strategy': 'Genotyping Array'},
#  {'uuid': 'be7ad45d-05de-4cc8-83d2-3bebaf45d6bd',
#   'data_type': 'Pathology Report',
#   'data_category': 'Clinical',
#   'experimental_strategy': 'N/A'},
#  {'uuid': 'b6aa44b9-8ac4-4b7e-9bee-56e741c7b7fc',
#   'data_type': 'Aligned Reads',
#   'data_category': 'Sequencing Reads',
#   'experimental_strategy': 'WGS'}]
